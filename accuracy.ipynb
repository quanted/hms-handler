# %%
from accuracy_assessment import DataTool

# %%
#import warnings
#warnings.filterwarnings("ignore")

# %%
dt=DataTool()

# %%
dt.plot_acc_compare()

# %%
-
# Out:
#   File "<ipython-input-16-60215a10e730>", line 1
#     -
#      ^
# SyntaxError: invalid syntax

# %%
dt.eco.loc[:,]
# Out:
#        area  perimeter  physiodd_  physiodd_i  fcode fencode  \
# 0    40.121     36.938          2          72    122     12b
# 1    21.976     39.951          3          59    131     13a
# 2     2.706     18.014          4          33    241     24a
# 3     3.636      8.140          5          34    231     23a
# 4    30.059     28.208          6          48    190      19
# ..      ...        ...        ...         ...    ...     ...
# 496   0.001      0.123        498         496     33      3c
# 497   0.000      0.072        499         498     33      3c
# 498   0.002      0.231        500         499     33      3c
# 499   0.001      0.162        501         501     33      3c
# 500   0.001      0.187        502         500     33      3c
#
#                     division                  province  \
# 0            INTERIOR PLAINS           CENTRAL LOWLAND
# 1            INTERIOR PLAINS              GREAT PLAINS
# 2    PACIFIC MOUNTAIN SYSTEM            PACIFIC BORDER
# 3    PACIFIC MOUNTAIN SYSTEM  CASCADE-SIERRA MOUNTAINS
# 4      ROCKY MOUNTAIN SYSTEM  NORTHERN ROCKY MOUNTAINS
# ..                       ...                       ...
# 496           ATLANTIC PLAIN             COASTAL PLAIN
# 497           ATLANTIC PLAIN             COASTAL PLAIN
# 498           ATLANTIC PLAIN             COASTAL PLAIN
# 499           ATLANTIC PLAIN             COASTAL PLAIN
# 500           ATLANTIC PLAIN             COASTAL PLAIN
#
#                          section  provcode  \
# 0                   WESTERN LAKE        12
# 1    MISSOURI PLATEAU, GLACIATED        13
# 2                   PUGET TROUGH        24
# 3     NORTHERN CASCADE MOUNTAINS        23
# 4                           None        19
# ..                           ...       ...
# 496                    FLORIDIAN         3
# 497                    FLORIDIAN         3
# 498                    FLORIDIAN         3
# 499                    FLORIDIAN         3
# 500                    FLORIDIAN         3
#
#                                               geometry
# 0    POLYGON ((-103.00201 49.00395, -102.94103 49.0...
# 1    POLYGON ((-113.55362 48.99719, -112.19278 48.9...
# 2    POLYGON ((-122.35828 47.59034, -122.33666 47.5...
# 3    POLYGON ((-122.14882 49.00173, -120.85696 48.9...
# 4    POLYGON ((-119.67419 49.00147, -118.84358 48.9...
# ..                                                 ...
# 496  POLYGON ((-81.42094 24.64500, -81.46506 24.666...
# 497  POLYGON ((-81.42094 24.64500, -81.41373 24.672...
# 498  POLYGON ((-81.70815 24.58081, -81.70338 24.599...
# 499  POLYGON ((-82.10853 24.56015, -82.10152 24.575...
# 500  POLYGON ((-81.81126 24.55392, -81.73983 24.581...
#
# [501 rows x 11 columns]

# %%
eco_list=dt.eco_geog.index.to_list()
eco_list
# Out:
# ['adirondack',
#  'appalachian plateaus',
#  'basin and range',
#  'blue ridge',
#  'cascade-sierra mountains',
#  'central lowland',
#  'coastal plain',
#  'colorado plateaus',
#  'columbia plateau',
#  'great plains',
#  'interior low plateaus',
#  'lower californian',
#  'middle rocky mountains',
#  'new england',
#  'northern rocky mountains',
#  'ouachita',
#  'ozark plateaus',
#  'pacific border',
#  'piedmont',
#  'southern rocky mountains',
#  'st. lawrence valley',
#  'superior upland',
#  'valley and ridge',
#  'wyoming basin']

# %%
import re
geog=dt.modeldict['geog_covs'][0]
params=dt.model_result.params
params.index=[f"{re.split('_',idx)[1].lower()} {geog}" for idx in params.index]
params
# Out:
# basin and range province             0.651305
# great plains province                0.705462
# new england province                 0.504495
# coastal plain province               0.754483
# st. lawrence valley province         0.672347
# appalachian plateaus province        0.602737
# adirondack province                  0.472044
# valley and ridge province            0.650664
# piedmont province                    0.763236
# blue ridge province                  0.681500
# central lowland province             0.560966
# interior low plateaus province       0.789312
# ozark plateaus province              0.653470
# ouachita province                    0.762125
# colorado plateaus province           0.530131
# cascade-sierra mountains province    0.646362
# columbia plateau province            0.377485
# pacific border province              0.754033
# dtype: float64

# %%
dt.params.index.to_list()
# Out:
# ['basin and range province',
#  'great plains province',
#  'new england province',
#  'coastal plain province',
#  'st. lawrence valley province',
#  'appalachian plateaus province',
#  'adirondack province',
#  'valley and ridge province',
#  'piedmont province',
#  'blue ridge province',
#  'central lowland province',
#  'interior low plateaus province',
#  'ozark plateaus province',
#  'ouachita province',
#  'colorado plateaus province',
#  'cascade-sierra mountains province',
#  'columbia plateau province',
#  'pacific border province']

# %%
dt.params
# Out:
# province
# basin and range province             0.651305
# great plains province                0.705462
# new england province                 0.504495
# coastal plain province               0.754483
# st. lawrence valley province         0.672347
# appalachian plateaus province        0.602737
# adirondack province                  0.472044
# valley and ridge province            0.650664
# piedmont province                    0.763236
# blue ridge province                  0.681500
# central lowland province             0.560966
# interior low plateaus province       0.789312
# ozark plateaus province              0.653470
# ouachita province                    0.762125
# colorado plateaus province           0.530131
# cascade-sierra mountains province    0.646362
# columbia plateau province            0.377485
# pacific border province              0.754033
# Name: coefficient, dtype: float64

# %%
dt.X_float_df

# %%
dt.param_gdf
# Out:
#                                                                    geometry  \
# adirondack                POLYGON ((-75.69115 44.03500, -75.68451 44.093...
# appalachian plateaus      POLYGON ((-84.23506 37.56641, -84.21626 37.569...
# basin and range           POLYGON ((-114.01513 36.09882, -114.01051 36.0...
# blue ridge                MULTIPOLYGON (((-79.86814 37.22866, -79.77254 ...
# cascade-sierra mountains  MULTIPOLYGON (((-120.99450 40.40145, -120.9458...
# central lowland           MULTIPOLYGON (((-82.67204 41.62373, -82.69279 ...
# coastal plain             MULTIPOLYGON (((-97.59593 27.31442, -97.58021 ...
# colorado plateaus         POLYGON ((-106.83543 35.56444, -106.83121 35.5...
# columbia plateau          POLYGON ((-111.33584 44.42163, -111.25562 44.3...
# great plains              POLYGON ((-101.34389 32.47313, -101.33547 32.4...
# interior low plateaus     POLYGON ((-89.42651 37.59848, -89.31336 37.594...
# lower californian         POLYGON ((-116.44614 33.06045, -116.41830 33.0...
# middle rocky mountains    POLYGON ((-110.13737 45.77462, -110.13851 45.7...
# new england               MULTIPOLYGON (((-71.19952 41.45124, -71.19952 ...
# northern rocky mountains  POLYGON ((-119.67419 49.00147, -118.84358 48.9...
# ouachita                  POLYGON ((-91.86934 35.06903, -91.94449 35.014...
# ozark plateaus            POLYGON ((-91.48744 35.60836, -91.55844 35.608...
# pacific border            MULTIPOLYGON (((-118.67183 34.76627, -118.6307...
# piedmont                  POLYGON ((-76.23408 40.37030, -76.15117 40.390...
# southern rocky mountains  POLYGON ((-106.40696 42.72720, -106.29897 42.7...
# st. lawrence valley       MULTIPOLYGON (((-72.71396 45.00648, -72.73470 ...
# superior upland           MULTIPOLYGON (((-92.05932 46.73702, -92.08446 ...
# valley and ridge          POLYGON ((-81.42378 37.28854, -81.41483 37.263...
# wyoming basin             POLYGON ((-106.96860 43.34317, -106.93162 43.2...
#
#                             area  perimeter  physiodd_  physiodd_i  fcode  \
# adirondack                 2.921      6.967        100         127    100
# appalachian plateaus       0.774      5.716        132         157     81
# basin and range           49.238     34.619        145         153    221
# blue ridge                 0.782      8.781        226         241     51
# cascade-sierra mountains   3.636      8.140          5          34    231
# central lowland           40.121     36.938          2          72    122
# coastal plain              0.104      3.401        159         167     31
# colorado plateaus          3.886      9.904        220          15    212
# columbia plateau          13.383     21.026         25          56    201
# great plains              21.976     39.951          3          59    131
# interior low plateaus     10.877     21.605        237         280    111
# lower californian          0.752      4.423        340         338    250
# middle rocky mountains    13.999     29.532         77           4    180
# new england               11.837     36.376         37          57     92
# northern rocky mountains  30.059     28.208          6          48    190
# ouachita                   2.252     10.101        313          29    151
# ozark plateaus            11.628     15.892        246          22    141
# pacific border             2.706     18.014          4          33    241
# piedmont                   0.587      5.056        192         210     42
# southern rocky mountains  12.244     25.734        151          14    160
# st. lawrence valley        1.225      8.957         95         114     70
# superior upland           12.770     26.727         12          79     10
# valley and ridge           0.887      5.801        143           7     63
# wyoming basin             11.109     22.546        141          12    170
#
#                          fencode                 division  \
# adirondack                    10    APPALACHIAN HIGHLANDS
# appalachian plateaus          8a    APPALACHIAN HIGHLANDS
# basin and range              22a    INTERMONTANE PLATEAUS
# blue ridge                    5a    APPALACHIAN HIGHLANDS
# cascade-sierra mountains     23a  PACIFIC MOUNTAIN SYSTEM
# central lowland              12b          INTERIOR PLAINS
# coastal plain                 3a           ATLANTIC PLAIN
# colorado plateaus            21b    INTERMONTANE PLATEAUS
# columbia plateau             20a    INTERMONTANE PLATEAUS
# great plains                 13a          INTERIOR PLAINS
# interior low plateaus        11a          INTERIOR PLAINS
# lower californian             25  PACIFIC MOUNTAIN SYSTEM
# middle rocky mountains        18    ROCKY MOUNTAIN SYSTEM
# new england                   9b    APPALACHIAN HIGHLANDS
# northern rocky mountains      19    ROCKY MOUNTAIN SYSTEM
# ouachita                     15a       INTERIOR HIGHLANDS
# ozark plateaus               14a       INTERIOR HIGHLANDS
# pacific border               24a  PACIFIC MOUNTAIN SYSTEM
# piedmont                      4b    APPALACHIAN HIGHLANDS
# southern rocky mountains      16    ROCKY MOUNTAIN SYSTEM
# st. lawrence valley           7a    APPALACHIAN HIGHLANDS
# superior upland                1        LAURENTIAN UPLAND
# valley and ridge              6c    APPALACHIAN HIGHLANDS
# wyoming basin                 17    ROCKY MOUNTAIN SYSTEM
#
#                                               section  provcode  coefficient
# adirondack                                       None        10          NaN
# appalachian plateaus                           MOHAWK         8          NaN
# basin and range                           GREAT BASIN        22          NaN
# blue ridge                                   NORTHERN         5          NaN
# cascade-sierra mountains   NORTHERN CASCADE MOUNTAINS        23          NaN
# central lowland                          WESTERN LAKE        12          NaN
# coastal plain                                 EMBAYED         3          NaN
# colorado plateaus                         UINTA BASIN        21          NaN
# columbia plateau                  WALLA WALLA PLATEAU        20          NaN
# great plains              MISSOURI PLATEAU, GLACIATED        13          NaN
# interior low plateaus                    HIGHLAND RIM        11          NaN
# lower californian                                None        25          NaN
# middle rocky mountains                           None        18          NaN
# new england                        NEW ENGLAND UPLAND         9          NaN
# northern rocky mountains                         None        19          NaN
# ouachita                              ARKANSAS VALLEY        15          NaN
# ozark plateaus             SPRINGFIELD-SALEM PLATEAUS        14          NaN
# pacific border                           PUGET TROUGH        24          NaN
# piedmont                            PIEDMONT LOWLANDS         4          NaN
# southern rocky mountains                         None        16          NaN
# st. lawrence valley                         CHAMPLAIN         7          NaN
# superior upland                                  None         1          NaN
# valley and ridge                        HUDSON VALLEY         6          NaN
# wyoming basin                                    None        17          NaN

# %%
-

# %%
dt.set_flat_c_stats_df()

# %%
dt.run_acc_compare(print_summary=True)

# %%
type(dt.model_result.params)

# %%
params=dt.model_result.params

# %%
p=params.reset_index()
p.columns=['a','b']
p

# %%
params

# %%
import pandas as pd
pd.DataFrame(,columns=['regressor','coefficient'])

# %%
dt.modeldict['geog_covs']=['section']
dt.set_flat_c_stats_df() #move inside run_acc_compare?
dt.run_acc_compare(print_summary=True)

# %%
-

# %%
dt.X_float_df.shape

# %%
dt.X_float_df.to_csv('xfloat.csv')

# %%
dt.set_flat_c_stats_df()

# %%
dt.flat_c_stats_df.head()
