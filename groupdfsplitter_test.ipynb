# %%
import numpy as np;import pandas as pd

# %%
from mylogger import myLogger

# %%
class GroupDFSplitter(myLogger):
    def __init__(self,n_reps):
        myLogger.__init__(self)
        self.n_reps=n_reps
    def get_df_split(self,groups):
        if type(groups) is pd.Series:
            groups=pd.DataFrame(groups,columns=['group'])
        inferred_group_name=groups.columns.to_list()[0]
        print(inferred_group_name)
        n=groups.shape[0]
        num_groups=groups.value_counts(subset=inferred_group_name).min()
        print('num_groups: ',num_groups)
        for seed in range(self.n_reps):
            shuf_grp=groups.sample(frac=1,replace=False,random_state=seed)
            print('\n\n\n\nshuffle_group:\n',shuf_grp)
            grp=shuf_grp.groupby(by=inferred_group_name).cumcount()
            for i in range(num_groups):
                print(f'\n\n\nsplit {seed*num_groups+i}')
                
                grp_bool=grp!=pd.Series([i]*n,name=grp.name,index=grp.index)
                #grp_bool=grp.map(lambda x:x in selector)
                #idx=pd.Series(np.arange(grp.shape[0]),index=grp.index)
                #grp_bool,_=grp_bool.align(groups,axis=0)
                #_,grp_bool=groups.align(grp_bool,axis=0,join='outer')
                yield grp_bool
                #yield idx[grp_bool].to_numpy()

# %%
midx=pd.MultiIndex.from_tuples([(f'left index {i//4}',f'right index {i}') for i in range(32)],names=['first_idx','second_idx'])
df=pd.DataFrame(np.arange(128).reshape(32,4),columns=['a','b','c','d'],index=midx)
group=pd.DataFrame(['A']*8+['B']*8+['C']*8+['D']*8,index=midx,columns=['cat'])
print('data:\n',df)
print('\n\ngrouping:\n',group)
# Out:
# data:
#                                 a    b    c    d
# first_idx    second_idx
# left index 0 right index 0     0    1    2    3
#              right index 1     4    5    6    7
#              right index 2     8    9   10   11
#              right index 3    12   13   14   15
# left index 1 right index 4    16   17   18   19
#              right index 5    20   21   22   23
#              right index 6    24   25   26   27
#              right index 7    28   29   30   31
# left index 2 right index 8    32   33   34   35
#              right index 9    36   37   38   39
#              right index 10   40   41   42   43
#              right index 11   44   45   46   47
# left index 3 right index 12   48   49   50   51
#              right index 13   52   53   54   55
#              right index 14   56   57   58   59
#              right index 15   60   61   62   63
# left index 4 right index 16   64   65   66   67
#              right index 17   68   69   70   71
#              right index 18   72   73   74   75
#              right index 19   76   77   78   79
# left index 5 right index 20   80   81   82   83
#              right index 21   84   85   86   87
#              right index 22   88   89   90   91
#              right index 23   92   93   94   95
# left index 6 right index 24   96   97   98   99
#              right index 25  100  101  102  103
#              right index 26  104  105  106  107
#              right index 27  108  109  110  111
# left index 7 right index 28  112  113  114  115
#              right index 29  116  117  118  119
#              right index 30  120  121  122  123
#              right index 31  124  125  126  127
#
#
# grouping:
#                              cat
# first_idx    second_idx
# left index 0 right index 0    A
#              right index 1    A
#              right index 2    A
#              right index 3    A
# left index 1 right index 4    A
#              right index 5    A
#              right index 6    A
#              right index 7    A
# left index 2 right index 8    B
#              right index 9    B
#              right index 10   B
#              right index 11   B
# left index 3 right index 12   B
#              right index 13   B
#              right index 14   B
#              right index 15   B
# left index 4 right index 16   C
#              right index 17   C
#              right index 18   C
#              right index 19   C
# left index 5 right index 20   C
#              right index 21   C
#              right index 22   C
#              right index 23   C
# left index 6 right index 24   D
#              right index 25   D
#              right index 26   D
#              right index 27   D
# left index 7 right index 28   D
#              right index 29   D
#              right index 30   D
#              right index 31   D

# %%
for bool_idx in GroupDFSplitter(2).get_df_split(group):
    print(df[bool_idx])
# Out:
# cat
# num_groups:  8
#
#
#
#
# shuffle_group:
#                              cat
# first_idx    second_idx
# left index 2 right index 11   B
# left index 5 right index 22   C
# left index 2 right index 10   B
# left index 0 right index 2    A
# left index 4 right index 16   C
# left index 3 right index 14   B
# left index 7 right index 28   D
# left index 6 right index 26   D
# left index 5 right index 20   C
# left index 3 right index 13   B
# left index 6 right index 24   D
# left index 1 right index 5    A
# left index 4 right index 17   C
# left index 2 right index 8    B
# left index 7 right index 30   D
# left index 6 right index 25   D
# left index 5 right index 23   C
# left index 0 right index 1    A
# left index 7 right index 31   D
# left index 1 right index 6    A
#              right index 4    A
# left index 4 right index 18   C
# left index 7 right index 29   D
# left index 4 right index 19   C
# left index 2 right index 9    B
# left index 1 right index 7    A
# left index 6 right index 27   D
# left index 0 right index 3    A
#              right index 0    A
# left index 5 right index 21   C
# left index 3 right index 15   B
#              right index 12   B
#
#
#
# split 0
#                                a    b    c    d
# first_idx    second_idx
# left index 0 right index 0     0    1    2    3
#              right index 1     4    5    6    7
#              right index 3    12   13   14   15
# left index 1 right index 4    16   17   18   19
#              right index 5    20   21   22   23
#              right index 6    24   25   26   27
#              right index 7    28   29   30   31
# left index 2 right index 8    32   33   34   35
#              right index 9    36   37   38   39
#              right index 10   40   41   42   43
# left index 3 right index 12   48   49   50   51
#              right index 13   52   53   54   55
#              right index 14   56   57   58   59
#              right index 15   60   61   62   63
# left index 4 right index 16   64   65   66   67
#              right index 17   68   69   70   71
#              right index 18   72   73   74   75
#              right index 19   76   77   78   79
# left index 5 right index 20   80   81   82   83
#              right index 21   84   85   86   87
#              right index 23   92   93   94   95
# left index 6 right index 24   96   97   98   99
#              right index 25  100  101  102  103
#              right index 26  104  105  106  107
#              right index 27  108  109  110  111
# left index 7 right index 29  116  117  118  119
#              right index 30  120  121  122  123
#              right index 31  124  125  126  127
#
#
#
# split 1
#                                a    b    c    d
# first_idx    second_idx
# left index 0 right index 0     0    1    2    3
#              right index 1     4    5    6    7
#              right index 2     8    9   10   11
#              right index 3    12   13   14   15
# left index 1 right index 4    16   17   18   19
#              right index 6    24   25   26   27
#              right index 7    28   29   30   31
# left index 2 right index 8    32   33   34   35
#              right index 9    36   37   38   39
#              right index 11   44   45   46   47
# left index 3 right index 12   48   49   50   51
#              right index 13   52   53   54   55
#              right index 14   56   57   58   59
#              right index 15   60   61   62   63
# left index 4 right index 17   68   69   70   71
#              right index 18   72   73   74   75
#              right index 19   76   77   78   79
# left index 5 right index 20   80   81   82   83
#              right index 21   84   85   86   87
#              right index 22   88   89   90   91
#              right index 23   92   93   94   95
# left index 6 right index 24   96   97   98   99
#              right index 25  100  101  102  103
#              right index 27  108  109  110  111
# left index 7 right index 28  112  113  114  115
#              right index 29  116  117  118  119
#              right index 30  120  121  122  123
#              right index 31  124  125  126  127
#
#
#
# split 2
#                                a    b    c    d
# first_idx    second_idx
# left index 0 right index 0     0    1    2    3
#              right index 2     8    9   10   11
#              right index 3    12   13   14   15
# left index 1 right index 4    16   17   18   19
#              right index 5    20   21   22   23
#              right index 6    24   25   26   27
#              right index 7    28   29   30   31
# left index 2 right index 8    32   33   34   35
#              right index 9    36   37   38   39
#              right index 10   40   41   42   43
#              right index 11   44   45   46   47
# left index 3 right index 12   48   49   50   51
#              right index 13   52   53   54   55
#              right index 15   60   61   62   63
# left index 4 right index 16   64   65   66   67
#              right index 17   68   69   70   71
#              right index 18   72   73   74   75
#              right index 19   76   77   78   79
# left index 5 right index 21   84   85   86   87
#              right index 22   88   89   90   91
#              right index 23   92   93   94   95
# left index 6 right index 25  100  101  102  103
#              right index 26  104  105  106  107
#              right index 27  108  109  110  111
# left index 7 right index 28  112  113  114  115
#              right index 29  116  117  118  119
#              right index 30  120  121  122  123
#              right index 31  124  125  126  127
#
#
#
# split 3
#                                a    b    c    d
# first_idx    second_idx
# left index 0 right index 0     0    1    2    3
#              right index 1     4    5    6    7
#              right index 2     8    9   10   11
#              right index 3    12   13   14   15
# left index 1 right index 4    16   17   18   19
#              right index 5    20   21   22   23
#              right index 7    28   29   30   31
# left index 2 right index 8    32   33   34   35
#              right index 9    36   37   38   39
#              right index 10   40   41   42   43
#              right index 11   44   45   46   47
# left index 3 right index 12   48   49   50   51
#              right index 14   56   57   58   59
#              right index 15   60   61   62   63
# left index 4 right index 16   64   65   66   67
#              right index 18   72   73   74   75
#              right index 19   76   77   78   79
# left index 5 right index 20   80   81   82   83
#              right index 21   84   85   86   87
#              right index 22   88   89   90   91
#              right index 23   92   93   94   95
# left index 6 right index 24   96   97   98   99
#              right index 25  100  101  102  103
#              right index 26  104  105  106  107
#              right index 27  108  109  110  111
# left index 7 right index 28  112  113  114  115
#              right index 29  116  117  118  119
#              right index 31  124  125  126  127
#
#
#
# split 4
#                                a    b    c    d
# first_idx    second_idx
# left index 0 right index 0     0    1    2    3
#              right index 1     4    5    6    7
#              right index 2     8    9   10   11
#              right index 3    12   13   14   15
# left index 1 right index 5    20   21   22   23
#              right index 6    24   25   26   27
#              right index 7    28   29   30   31
# left index 2 right index 9    36   37   38   39
#              right index 10   40   41   42   43
#              right index 11   44   45   46   47
# left index 3 right index 12   48   49   50   51
#              right index 13   52   53   54   55
#              right index 14   56   57   58   59
#              right index 15   60   61   62   63
# left index 4 right index 16   64   65   66   67
#              right index 17   68   69   70   71
#              right index 18   72   73   74   75
#              right index 19   76   77   78   79
# left index 5 right index 20   80   81   82   83
#              right index 21   84   85   86   87
#              right index 22   88   89   90   91
# left index 6 right index 24   96   97   98   99
#              right index 26  104  105  106  107
#              right index 27  108  109  110  111
# left index 7 right index 28  112  113  114  115
#              right index 29  116  117  118  119
#              right index 30  120  121  122  123
#              right index 31  124  125  126  127
#
#
#
# split 5
#                                a    b    c    d
# first_idx    second_idx
# left index 0 right index 0     0    1    2    3
#              right index 1     4    5    6    7
#              right index 2     8    9   10   11
#              right index 3    12   13   14   15
# left index 1 right index 4    16   17   18   19
#              right index 5    20   21   22   23
#              right index 6    24   25   26   27
# left index 2 right index 8    32   33   34   35
#              right index 10   40   41   42   43
#              right index 11   44   45   46   47
# left index 3 right index 12   48   49   50   51
#              right index 13   52   53   54   55
#              right index 14   56   57   58   59
#              right index 15   60   61   62   63
# left index 4 right index 16   64   65   66   67
#              right index 17   68   69   70   71
#              right index 19   76   77   78   79
# left index 5 right index 20   80   81   82   83
#              right index 21   84   85   86   87
#              right index 22   88   89   90   91
#              right index 23   92   93   94   95
# left index 6 right index 24   96   97   98   99
#              right index 25  100  101  102  103
#              right index 26  104  105  106  107
#              right index 27  108  109  110  111
# left index 7 right index 28  112  113  114  115
#              right index 29  116  117  118  119
#              right index 30  120  121  122  123
#
#
#
# split 6
#                                a    b    c    d
# first_idx    second_idx
# left index 0 right index 0     0    1    2    3
#              right index 1     4    5    6    7
#              right index 2     8    9   10   11
# left index 1 right index 4    16   17   18   19
#              right index 5    20   21   22   23
#              right index 6    24   25   26   27
#              right index 7    28   29   30   31
# left index 2 right index 8    32   33   34   35
#              right index 9    36   37   38   39
#              right index 10   40   41   42   43
#              right index 11   44   45   46   47
# left index 3 right index 12   48   49   50   51
#              right index 13   52   53   54   55
#              right index 14   56   57   58   59
# left index 4 right index 16   64   65   66   67
#              right index 17   68   69   70   71
#              right index 18   72   73   74   75
# left index 5 right index 20   80   81   82   83
#              right index 21   84   85   86   87
#              right index 22   88   89   90   91
#              right index 23   92   93   94   95
# left index 6 right index 24   96   97   98   99
#              right index 25  100  101  102  103
#              right index 26  104  105  106  107
#              right index 27  108  109  110  111
# left index 7 right index 28  112  113  114  115
#              right index 30  120  121  122  123
#              right index 31  124  125  126  127
#
#
#
# split 7
#                                a    b    c    d
# first_idx    second_idx
# left index 0 right index 1     4    5    6    7
#              right index 2     8    9   10   11
#              right index 3    12   13   14   15
# left index 1 right index 4    16   17   18   19
#              right index 5    20   21   22   23
#              right index 6    24   25   26   27
#              right index 7    28   29   30   31
# left index 2 right index 8    32   33   34   35
#              right index 9    36   37   38   39
#              right index 10   40   41   42   43
#              right index 11   44   45   46   47
# left index 3 right index 13   52   53   54   55
#              right index 14   56   57   58   59
#              right index 15   60   61   62   63
# left index 4 right index 16   64   65   66   67
#              right index 17   68   69   70   71
#              right index 18   72   73   74   75
#              right index 19   76   77   78   79
# left index 5 right index 20   80   81   82   83
#              right index 22   88   89   90   91
#              right index 23   92   93   94   95
# left index 6 right index 24   96   97   98   99
#              right index 25  100  101  102  103
#              right index 26  104  105  106  107
# left index 7 right index 28  112  113  114  115
#              right index 29  116  117  118  119
#              right index 30  120  121  122  123
#              right index 31  124  125  126  127
#
#
#
#
# shuffle_group:
#                              cat
# first_idx    second_idx
# left index 6 right index 27   D
# left index 0 right index 3    A
# left index 5 right index 22   C
# left index 4 right index 18   C
# left index 5 right index 23   C
# left index 4 right index 17   C
# left index 5 right index 21   C
# left index 7 right index 28   D
# left index 4 right index 19   C
# left index 3 right index 14   B
# left index 6 right index 24   D
# left index 2 right index 10   B
# left index 5 right index 20   C
# left index 6 right index 26   D
# left index 1 right index 4    A
# left index 0 right index 2    A
# left index 6 right index 25   D
# left index 1 right index 6    A
# left index 3 right index 13   B
# left index 1 right index 7    A
# left index 7 right index 29   D
# left index 0 right index 1    A
# left index 4 right index 16   C
# left index 0 right index 0    A
# left index 3 right index 15   B
# left index 7 right index 31   D
#              right index 30   D
# left index 2 right index 9    B
#              right index 8    B
# left index 3 right index 12   B
# left index 2 right index 11   B
# left index 1 right index 5    A
#
#
#
# split 8
#                                a    b    c    d
# first_idx    second_idx
# left index 0 right index 0     0    1    2    3
#              right index 1     4    5    6    7
#              right index 2     8    9   10   11
# left index 1 right index 4    16   17   18   19
#              right index 5    20   21   22   23
#              right index 6    24   25   26   27
#              right index 7    28   29   30   31
# left index 2 right index 8    32   33   34   35
#              right index 9    36   37   38   39
#              right index 10   40   41   42   43
#              right index 11   44   45   46   47
# left index 3 right index 12   48   49   50   51
#              right index 13   52   53   54   55
#              right index 15   60   61   62   63
# left index 4 right index 16   64   65   66   67
#              right index 17   68   69   70   71
#              right index 18   72   73   74   75
#              right index 19   76   77   78   79
# left index 5 right index 20   80   81   82   83
#              right index 21   84   85   86   87
#              right index 23   92   93   94   95
# left index 6 right index 24   96   97   98   99
#              right index 25  100  101  102  103
#              right index 26  104  105  106  107
# left index 7 right index 28  112  113  114  115
#              right index 29  116  117  118  119
#              right index 30  120  121  122  123
#              right index 31  124  125  126  127
#
#
#
# split 9
#                                a    b    c    d
# first_idx    second_idx
# left index 0 right index 0     0    1    2    3
#              right index 1     4    5    6    7
#              right index 2     8    9   10   11
#              right index 3    12   13   14   15
# left index 1 right index 5    20   21   22   23
#              right index 6    24   25   26   27
#              right index 7    28   29   30   31
# left index 2 right index 8    32   33   34   35
#              right index 9    36   37   38   39
#              right index 11   44   45   46   47
# left index 3 right index 12   48   49   50   51
#              right index 13   52   53   54   55
#              right index 14   56   57   58   59
#              right index 15   60   61   62   63
# left index 4 right index 16   64   65   66   67
#              right index 17   68   69   70   71
#              right index 19   76   77   78   79
# left index 5 right index 20   80   81   82   83
#              right index 21   84   85   86   87
#              right index 22   88   89   90   91
#              right index 23   92   93   94   95
# left index 6 right index 24   96   97   98   99
#              right index 25  100  101  102  103
#              right index 26  104  105  106  107
#              right index 27  108  109  110  111
# left index 7 right index 29  116  117  118  119
#              right index 30  120  121  122  123
#              right index 31  124  125  126  127
#
#
#
# split 10
#                                a    b    c    d
# first_idx    second_idx
# left index 0 right index 0     0    1    2    3
#              right index 1     4    5    6    7
#              right index 3    12   13   14   15
# left index 1 right index 4    16   17   18   19
#              right index 5    20   21   22   23
#              right index 6    24   25   26   27
#              right index 7    28   29   30   31
# left index 2 right index 8    32   33   34   35
#              right index 9    36   37   38   39
#              right index 10   40   41   42   43
#              right index 11   44   45   46   47
# left index 3 right index 12   48   49   50   51
#              right index 14   56   57   58   59
#              right index 15   60   61   62   63
# left index 4 right index 16   64   65   66   67
#              right index 17   68   69   70   71
#              right index 18   72   73   74   75
#              right index 19   76   77   78   79
# left index 5 right index 20   80   81   82   83
#              right index 21   84   85   86   87
#              right index 22   88   89   90   91
# left index 6 right index 25  100  101  102  103
#              right index 26  104  105  106  107
#              right index 27  108  109  110  111
# left index 7 right index 28  112  113  114  115
#              right index 29  116  117  118  119
#              right index 30  120  121  122  123
#              right index 31  124  125  126  127
#
#
#
# split 11
#                                a    b    c    d
# first_idx    second_idx
# left index 0 right index 0     0    1    2    3
#              right index 1     4    5    6    7
#              right index 2     8    9   10   11
#              right index 3    12   13   14   15
# left index 1 right index 4    16   17   18   19
#              right index 5    20   21   22   23
#              right index 7    28   29   30   31
# left index 2 right index 8    32   33   34   35
#              right index 9    36   37   38   39
#              right index 10   40   41   42   43
#              right index 11   44   45   46   47
# left index 3 right index 12   48   49   50   51
#              right index 13   52   53   54   55
#              right index 14   56   57   58   59
# left index 4 right index 16   64   65   66   67
#              right index 18   72   73   74   75
#              right index 19   76   77   78   79
# left index 5 right index 20   80   81   82   83
#              right index 21   84   85   86   87
#              right index 22   88   89   90   91
#              right index 23   92   93   94   95
# left index 6 right index 24   96   97   98   99
#              right index 25  100  101  102  103
#              right index 27  108  109  110  111
# left index 7 right index 28  112  113  114  115
#              right index 29  116  117  118  119
#              right index 30  120  121  122  123
#              right index 31  124  125  126  127
#
#
#
# split 12
#                                a    b    c    d
# first_idx    second_idx
# left index 0 right index 0     0    1    2    3
#              right index 1     4    5    6    7
#              right index 2     8    9   10   11
#              right index 3    12   13   14   15
# left index 1 right index 4    16   17   18   19
#              right index 5    20   21   22   23
#              right index 6    24   25   26   27
# left index 2 right index 8    32   33   34   35
#              right index 10   40   41   42   43
#              right index 11   44   45   46   47
# left index 3 right index 12   48   49   50   51
#              right index 13   52   53   54   55
#              right index 14   56   57   58   59
#              right index 15   60   61   62   63
# left index 4 right index 16   64   65   66   67
#              right index 17   68   69   70   71
#              right index 18   72   73   74   75
#              right index 19   76   77   78   79
# left index 5 right index 20   80   81   82   83
#              right index 22   88   89   90   91
#              right index 23   92   93   94   95
# left index 6 right index 24   96   97   98   99
#              right index 26  104  105  106  107
#              right index 27  108  109  110  111
# left index 7 right index 28  112  113  114  115
#              right index 29  116  117  118  119
#              right index 30  120  121  122  123
#              right index 31  124  125  126  127
#
#
#
# split 13
#                                a    b    c    d
# first_idx    second_idx
# left index 0 right index 0     0    1    2    3
#              right index 2     8    9   10   11
#              right index 3    12   13   14   15
# left index 1 right index 4    16   17   18   19
#              right index 5    20   21   22   23
#              right index 6    24   25   26   27
#              right index 7    28   29   30   31
# left index 2 right index 9    36   37   38   39
#              right index 10   40   41   42   43
#              right index 11   44   45   46   47
# left index 3 right index 12   48   49   50   51
#              right index 13   52   53   54   55
#              right index 14   56   57   58   59
#              right index 15   60   61   62   63
# left index 4 right index 16   64   65   66   67
#              right index 17   68   69   70   71
#              right index 18   72   73   74   75
# left index 5 right index 20   80   81   82   83
#              right index 21   84   85   86   87
#              right index 22   88   89   90   91
#              right index 23   92   93   94   95
# left index 6 right index 24   96   97   98   99
#              right index 25  100  101  102  103
#              right index 26  104  105  106  107
#              right index 27  108  109  110  111
# left index 7 right index 28  112  113  114  115
#              right index 30  120  121  122  123
#              right index 31  124  125  126  127
#
#
#
# split 14
#                                a    b    c    d
# first_idx    second_idx
# left index 0 right index 1     4    5    6    7
#              right index 2     8    9   10   11
#              right index 3    12   13   14   15
# left index 1 right index 4    16   17   18   19
#              right index 5    20   21   22   23
#              right index 6    24   25   26   27
#              right index 7    28   29   30   31
# left index 2 right index 8    32   33   34   35
#              right index 9    36   37   38   39
#              right index 10   40   41   42   43
#              right index 11   44   45   46   47
# left index 3 right index 13   52   53   54   55
#              right index 14   56   57   58   59
#              right index 15   60   61   62   63
# left index 4 right index 16   64   65   66   67
#              right index 17   68   69   70   71
#              right index 18   72   73   74   75
#              right index 19   76   77   78   79
# left index 5 right index 21   84   85   86   87
#              right index 22   88   89   90   91
#              right index 23   92   93   94   95
# left index 6 right index 24   96   97   98   99
#              right index 25  100  101  102  103
#              right index 26  104  105  106  107
#              right index 27  108  109  110  111
# left index 7 right index 28  112  113  114  115
#              right index 29  116  117  118  119
#              right index 30  120  121  122  123
#
#
#
# split 15
#                                a    b    c    d
# first_idx    second_idx
# left index 0 right index 0     0    1    2    3
#              right index 1     4    5    6    7
#              right index 2     8    9   10   11
#              right index 3    12   13   14   15
# left index 1 right index 4    16   17   18   19
#              right index 6    24   25   26   27
#              right index 7    28   29   30   31
# left index 2 right index 8    32   33   34   35
#              right index 9    36   37   38   39
#              right index 10   40   41   42   43
# left index 3 right index 12   48   49   50   51
#              right index 13   52   53   54   55
#              right index 14   56   57   58   59
#              right index 15   60   61   62   63
# left index 4 right index 17   68   69   70   71
#              right index 18   72   73   74   75
#              right index 19   76   77   78   79
# left index 5 right index 20   80   81   82   83
#              right index 21   84   85   86   87
#              right index 22   88   89   90   91
#              right index 23   92   93   94   95
# left index 6 right index 24   96   97   98   99
#              right index 25  100  101  102  103
#              right index 26  104  105  106  107
#              right index 27  108  109  110  111
# left index 7 right index 28  112  113  114  115
#              right index 29  116  117  118  119
#              right index 31  124  125  126  127
# <ipython-input-5-0bcbad84f294>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[bool_idx])
# <ipython-input-5-0bcbad84f294>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[bool_idx])
# <ipython-input-5-0bcbad84f294>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[bool_idx])
# <ipython-input-5-0bcbad84f294>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[bool_idx])
# <ipython-input-5-0bcbad84f294>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[bool_idx])
# <ipython-input-5-0bcbad84f294>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[bool_idx])
# <ipython-input-5-0bcbad84f294>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[bool_idx])
# <ipython-input-5-0bcbad84f294>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[bool_idx])
# <ipython-input-5-0bcbad84f294>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[bool_idx])
# <ipython-input-5-0bcbad84f294>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[bool_idx])
# <ipython-input-5-0bcbad84f294>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[bool_idx])
# <ipython-input-5-0bcbad84f294>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[bool_idx])
# <ipython-input-5-0bcbad84f294>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[bool_idx])
# <ipython-input-5-0bcbad84f294>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[bool_idx])
# <ipython-input-5-0bcbad84f294>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[bool_idx])
# <ipython-input-5-0bcbad84f294>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[bool_idx])

# %%
assert False,'stop'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-6-70812de2713f> in <module>
# ----> 1 assert False,'stop'
#
# AssertionError: stop

# %%
print('original group\n',group)
for seed in range(2):
    shuf_grp=group.sample(frac=1,replace=False,random_state=seed)
    print('shuffled:\n',shuf_grp,'\n')
    for i in range(4):
        selector=list(range(4))
        selector.pop(i)
        print(f'drop {i}\n')
        grp=shuf_grp.groupby(by='cat').cumcount()
        #df_temp['group']=df_temp.groupby('e').cumcount()
        grp_bool=grp.map(lambda x:x in selector)
        df_i=df[grp_bool]
        print(df_i)
        n=group.shape[0]
        #print(df_temp[df_temp['group'].map(lambda x:x in selector)],'\n\n\n')

# %%
"""for seed in range(2):
    df_temp=df.sample(frac=1,replace=False,random_state=seed)
    print('shuffled:\n',df_temp,'\n')
    for i in range(4):
        selector=list(range(4))
        selector.pop(i)
        print(f'drop {i}\n')
        df_temp['group']=df_temp.groupby('e').cumcount()
        print(df_temp[df_temp['group'].map(lambda x:x in selector)],'\n\n\n')"""

# %%
df_g2=df_g.cumcount()
df_g2

# %%
arr=np.asfortranarray(df.to_numpy)

# %%
arr.flags['F_CONTIGUOUS']
